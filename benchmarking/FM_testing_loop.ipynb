# %%
import os
import json
import time
import numpy as np
from qiskit import transpile
from disqco.graphs.GCP_hypergraph import QuantumCircuitHyperGraph
from disqco.circuits.cp_fraction import cp_fraction
from disqco.parti.FM.FM_main import *
from disqco.parti.FM.multilevel_FM import *
import math as mt

###############################################################################
# Set up JSON file for storing *all* iteration results (detailed data)
###############################################################################
detailed_filename = "benchmark_results_FM_fixed_levels_stoch.json"

if os.path.exists(detailed_filename):
    with open(detailed_filename, "r") as f:
        detailed_results = json.load(f)
else:
    detailed_results = []

###############################################################################
# Set up JSON file for *aggregated* results (mean cost/time)
###############################################################################
means_filename = "benchmark_means_FM_fixed_levels_stoch.json"

if os.path.exists(means_filename):
    with open(means_filename, "r") as f:
        mean_results = json.load(f)
else:
    mean_results = []

sizes = range(16, 97, 8)

for i, num_qubits in enumerate(sizes):
    # For each increase of 8 qubits, increase the number of partitions by 1
    num_partitions = 2 + i

    # Create an All-to-All network
    qpu_info = [int(num_qubits / num_partitions) + 1 for _ in range(num_partitions)]
    
    # Sweep the fraction parameter from 0.1 to 0.9
    for fraction in np.arange(0.3, 0.9, 0.2):
        
        # Collect data for computing means across 10 iterations
        iteration_data = []
        
        for iteration in range(5):

            
            
            # -------------------------
            # 1. Define/redefine circuit
            # -------------------------
            circuit = cp_fraction(num_qubits, num_qubits, fraction)
            base_graph = QuantumCircuitHyperGraph(circuit, group_gates=True, anti_diag=True)
            depth = base_graph.depth
            num_levels = np.ceil(mt.log2(depth))
            initial_assignment = set_initial_partitions(qpu_info,num_qubits, depth ,num_partitions, reduced=True)
            
            # -------------------------
            # 2. Fine-grained partitioning
            # -------------------------
            graph_list = [base_graph]
            mapping_list = [{i : set([i]) for i in range(depth)}]

            assignment_list_f, cost_list_f, time_list_f = multilevel_FM(graph_list,
                                                                  mapping_list,
                                                                  initial_assignment,
                                                                    qpu_info,
                                                                    limit = num_qubits*0.125,
                                                                    pass_list= [5*num_levels],
                                                                    stochastic=True,
                                                                    lock_nodes=False,
                                                                    log = False,
                                                                    add_initial = False,
                                                                    costs = None)
            total_time_f = sum(time_list_f)
            min_cost_f = min(cost_list_f)
            # -------------------------
            # 3. Window-based refinement
            # -------------------------

            assignment_list_w, cost_list_w, time_list_w = MLFM_window(base_graph, 
                num_levels=num_levels,
                initial_assignment=initial_assignment,  
                qpu_info= qpu_info, 
                limit = num_qubits*0.125, 
                pass_list= [5]*(num_levels+2), 
                stochastic=True, 
                lock_nodes=False,
                log = False,
                add_initial = False,
                costs = None)
            
            total_time_w = sum(time_list_w)
            min_cost_w = min(cost_list_w)

            
            # -------------------------
            # 4. Block refinement
            # -------------------------
            assignment_list_b, cost_list_b, time_list_b = MLFM_blocks(base_graph,
                                            num_levels=num_levels,
                                            initial_assignment=initial_assignment,  
                                            qpu_info= qpu_info, 
                                            limit = num_qubits*0.125, 
                                            pass_list= [5]*(num_levels+2), 
                                            stochastic=True, 
                                            lock_nodes=False,
                                            log = False,
                                            add_initial = False,
                                            costs = None,
                                            full = False)
            
            total_time_b = sum(time_list_b)
            min_cost_b = min(cost_list_b)
            
            # -------------------------
            # 5. Recursive refinement
            # -------------------------
            assignment_list_r, cost_list_r, time_list_r = MLFM_recursive(base_graph,
                                        initial_assignment,  
                                        qpu_info, 
                                        limit = num_qubits*0.125, 
                                        pass_list= [5]*(num_levels+2), 
                                        stochastic=True, 
                                        lock_nodes=False,
                                        log = False,
                                        add_initial = False,
                                        costs = None)
            
            total_time_r = sum(time_list_r)
            min_cost_r = min(cost_list_r)

            
            # -------------------------
            # 6. Store iteration-level results
            # -------------------------
            result_entry = {
                "num_qubits": num_qubits,
                "num_partitions": num_partitions,
                "fraction": float(fraction),
                "iteration": iteration,
                "f_cost": min_cost_f,
                "w_cost": min_cost_w,
                "b_cost": min_cost_b,
                "r_cost":  min_cost_r,
                "time_f": total_time_f,
                "time_w": total_time_w,
                "time_b": total_time_b,
                "time_r": total_time_r,
            }
            
            detailed_results.append(result_entry)
            iteration_data.append(result_entry)
            
            # Update detailed JSON right away
            with open(detailed_filename, "w") as f:
                json.dump(detailed_results, f, indent=2)
        
        # ---------------------------------------------------------------------
        # After 10 iterations, compute the means and log them
        # ---------------------------------------------------------------------
        f_cost_list = [x["f_cost"] for x in iteration_data]
        w_cost_list = [x["w_cost"] for x in iteration_data]
        b_cost_list = [x["b_cost"] for x in iteration_data]
        r_cost_list = [x["r_cost"] for x in iteration_data]
        
        f_time_list = [x["time_f"] for x in iteration_data]
        w_time_list = [x["time_w"] for x in iteration_data]
        b_time_list = [x["time_b"] for x in iteration_data]
        r_time_list = [x["time_r"] for x in iteration_data]
        
        mean_f_cost = float(np.mean(f_cost_list))
        mean_w_cost = float(np.mean(w_cost_list))
        mean_b_cost = float(np.mean(b_cost_list))
        mean_r_cost = float(np.mean(r_cost_list))
        
        mean_f_time = float(np.mean(f_time_list))
        mean_w_time = float(np.mean(w_time_list))
        mean_b_time = float(np.mean(b_time_list))
        mean_r_time = float(np.mean(r_time_list))
        
        # Print to console for quick logging
        print("=============================================")
        print(f"Finished 10 iterations for:")
        print(f"  # Qubits: {num_qubits}, # Partitions: {num_partitions}, fraction={fraction}")
        print("Mean Costs:")
        print(f"  `Fine`:    {mean_f_cost:.3f}")
        print(f"  Window: {mean_w_cost:.3f}")
        print(f"  Block: {mean_b_cost:.3f}")
        print(f"  Recursive:{mean_r_cost:.3f}")
        print("Mean Times (s):")
        print(f"  Fine:    {mean_f_time:.3f}")
        print(f"  Window: {mean_w_time:.3f}")
        print(f"  Block: {mean_b_time:.3f}")
        print(f"  Recursive:{mean_r_time:.3f}")
        print("=============================================")
        
        # Store the aggregated means in a separate JSON
        mean_entry = {
            "num_qubits": num_qubits,
            "num_partitions": num_partitions,
            "fraction": float(fraction),
            "mean_f_cost": mean_f_cost,
            "mean_w_cost": mean_w_cost,
            "mean_b_cost": mean_b_cost,
            "mean_r_cost": mean_r_cost,
            "mean_f_time": mean_f_time,
            "mean_w_time": mean_w_time,
            "mean_b_time": mean_b_time,
            "mean_r_time": mean_r_time,
        }
        
        mean_results.append(mean_entry)
        
        # Update the means JSON file
        with open(means_filename, "w") as f:
            json.dump(mean_results, f, indent=2)

print("Benchmarking completed. Detailed results saved to", detailed_filename)
print("Aggregated means saved to", means_filename)
# Out:
# =============================================
# Finished 10 iterations for:
#   # Qubits: 16, # Partitions: 2, fraction=0.3
# Mean Costs:
#   `Fine`:    13.000
#   Window: 6.400
#   Block: 10.400
#   Recursive:5.400
# Mean Times (s):
#   Fine:    0.030
#   Window: 0.022
#   Block: 0.021
#   Recursive:0.033
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 16, # Partitions: 2, fraction=0.5
# Mean Costs:
#   `Fine`:    22.800
#   Window: 13.000
#   Block: 19.000
#   Recursive:13.400
# Mean Times (s):
#   Fine:    0.032
#   Window: 0.024
#   Block: 0.022
#   Recursive:0.035
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 16, # Partitions: 2, fraction=0.7
# Mean Costs:
#   `Fine`:    21.800
#   Window: 16.200
#   Block: 19.400
#   Recursive:15.800
# Mean Times (s):
#   Fine:    0.037
#   Window: 0.028
#   Block: 0.025
#   Recursive:0.039
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 16, # Partitions: 2, fraction=0.9
# Mean Costs:
#   `Fine`:    18.600
#   Window: 14.200
#   Block: 16.800
#   Recursive:13.600
# Mean Times (s):
#   Fine:    0.045
#   Window: 0.035
#   Block: 0.030
#   Recursive:0.044
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 24, # Partitions: 3, fraction=0.3
# Mean Costs:
#   `Fine`:    47.200
#   Window: 27.800
#   Block: 42.600
#   Recursive:27.000
# Mean Times (s):
#   Fine:    0.103
#   Window: 0.076
#   Block: 0.070
#   Recursive:0.136
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 24, # Partitions: 3, fraction=0.5
# Mean Costs:
#   `Fine`:    67.800
#   Window: 49.200
#   Block: 61.000
#   Recursive:44.800
# Mean Times (s):
#   Fine:    0.113
#   Window: 0.085
#   Block: 0.079
#   Recursive:0.133
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 24, # Partitions: 3, fraction=0.7
# Mean Costs:
#   `Fine`:    79.000
#   Window: 58.400
#   Block: 72.800
#   Recursive:56.400
# Mean Times (s):
#   Fine:    0.132
#   Window: 0.101
#   Block: 0.107
#   Recursive:0.164
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 24, # Partitions: 3, fraction=0.9
# Mean Costs:
#   `Fine`:    65.400
#   Window: 50.000
#   Block: 59.400
#   Recursive:47.800
# Mean Times (s):
#   Fine:    0.184
#   Window: 0.140
#   Block: 0.128
#   Recursive:0.202
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 32, # Partitions: 4, fraction=0.3
# Mean Costs:
#   `Fine`:    95.800
#   Window: 67.000
#   Block: 92.200
#   Recursive:61.200
# Mean Times (s):
#   Fine:    0.325
#   Window: 0.241
#   Block: 0.211
#   Recursive:0.294
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 32, # Partitions: 4, fraction=0.5
# Mean Costs:
#   `Fine`:    140.400
#   Window: 109.800
#   Block: 130.000
#   Recursive:96.200
# Mean Times (s):
#   Fine:    0.368
#   Window: 0.262
#   Block: 0.238
#   Recursive:0.338
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 32, # Partitions: 4, fraction=0.7
# Mean Costs:
#   `Fine`:    170.200
#   Window: 142.000
#   Block: 158.600
#   Recursive:128.000
# Mean Times (s):
#   Fine:    0.427
#   Window: 0.322
#   Block: 0.285
#   Recursive:0.377
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 32, # Partitions: 4, fraction=0.9
# Mean Costs:
#   `Fine`:    138.600
#   Window: 122.400
#   Block: 132.600
#   Recursive:102.400
# Mean Times (s):
#   Fine:    0.659
#   Window: 0.481
#   Block: 0.441
#   Recursive:0.570
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 40, # Partitions: 5, fraction=0.3
# Mean Costs:
#   `Fine`:    160.200
#   Window: 114.000
#   Block: 154.800
#   Recursive:108.400
# Mean Times (s):
#   Fine:    0.706
#   Window: 0.471
#   Block: 0.449
#   Recursive:0.681
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 40, # Partitions: 5, fraction=0.5
# Mean Costs:
#   `Fine`:    257.000
#   Window: 196.400
#   Block: 243.200
#   Recursive:186.400
# Mean Times (s):
#   Fine:    0.802
#   Window: 0.558
#   Block: 0.531
#   Recursive:0.797
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 40, # Partitions: 5, fraction=0.7
# Mean Costs:
#   `Fine`:    303.800
#   Window: 258.400
#   Block: 281.800
#   Recursive:239.200
# Mean Times (s):
#   Fine:    0.959
#   Window: 0.689
#   Block: 0.653
#   Recursive:0.916
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 40, # Partitions: 5, fraction=0.9
# Mean Costs:
#   `Fine`:    250.000
#   Window: 209.200
#   Block: 233.200
#   Recursive:195.000
# Mean Times (s):
#   Fine:    1.509
#   Window: 1.074
#   Block: 0.969
#   Recursive:1.240
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 48, # Partitions: 6, fraction=0.3
# Mean Costs:
#   `Fine`:    260.600
#   Window: 207.600
#   Block: 252.600
#   Recursive:179.600
# Mean Times (s):
#   Fine:    1.301
#   Window: 0.940
#   Block: 0.830
#   Recursive:1.245
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 48, # Partitions: 6, fraction=0.5
# Mean Costs:
#   `Fine`:    394.200
#   Window: 345.400
#   Block: 380.400
#   Recursive:295.200
# Mean Times (s):
#   Fine:    1.435
#   Window: 1.077
#   Block: 0.937
#   Recursive:1.435
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 48, # Partitions: 6, fraction=0.7
# Mean Costs:
#   `Fine`:    483.800
#   Window: 444.800
#   Block: 464.400
#   Recursive:384.200
# Mean Times (s):
#   Fine:    1.759
#   Window: 1.338
#   Block: 1.155
#   Recursive:1.751
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 48, # Partitions: 6, fraction=0.9
# Mean Costs:
#   `Fine`:    402.200
#   Window: 387.400
#   Block: 383.000
#   Recursive:335.200
# Mean Times (s):
#   Fine:    2.768
#   Window: 1.929
#   Block: 1.790
#   Recursive:2.365
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 56, # Partitions: 7, fraction=0.3
# Mean Costs:
#   `Fine`:    374.000
#   Window: 288.800
#   Block: 366.200
#   Recursive:274.600
# Mean Times (s):
#   Fine:    2.253
#   Window: 1.467
#   Block: 1.399
#   Recursive:2.101
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 56, # Partitions: 7, fraction=0.5
# Mean Costs:
#   `Fine`:    570.000
#   Window: 473.800
#   Block: 555.000
#   Recursive:442.200
# Mean Times (s):
#   Fine:    2.408
#   Window: 1.721
#   Block: 1.592
#   Recursive:2.274
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 56, # Partitions: 7, fraction=0.7
# Mean Costs:
#   `Fine`:    690.000
#   Window: 613.600
#   Block: 664.000
#   Recursive:555.800
# Mean Times (s):
#   Fine:    2.891
#   Window: 2.159
#   Block: 1.915
#   Recursive:2.696
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 56, # Partitions: 7, fraction=0.9
# Mean Costs:
#   `Fine`:    611.200
#   Window: 540.800
#   Block: 589.600
#   Recursive:500.000
# Mean Times (s):
#   Fine:    4.623
#   Window: 3.527
#   Block: 3.223
#   Recursive:3.896
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 64, # Partitions: 8, fraction=0.3
# Mean Costs:
#   `Fine`:    477.400
#   Window: 428.400
#   Block: 464.800
#   Recursive:360.600
# Mean Times (s):
#   Fine:    4.295
#   Window: 2.855
#   Block: 2.770
#   Recursive:3.346
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 64, # Partitions: 8, fraction=0.5
# Mean Costs:
#   `Fine`:    756.200
#   Window: 698.000
#   Block: 731.200
#   Recursive:600.200
# Mean Times (s):
#   Fine:    4.612
#   Window: 3.348
#   Block: 3.057
#   Recursive:3.678
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 64, # Partitions: 8, fraction=0.7
# Mean Costs:
#   `Fine`:    942.000
#   Window: 922.200
#   Block: 903.600
#   Recursive:768.400
# Mean Times (s):
#   Fine:    5.460
#   Window: 3.902
#   Block: 3.659
#   Recursive:4.337
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 64, # Partitions: 8, fraction=0.9
# Mean Costs:
#   `Fine`:    841.800
#   Window: 829.800
#   Block: 797.000
#   Recursive:679.800
# Mean Times (s):
#   Fine:    8.779
#   Window: 6.181
#   Block: 5.734
#   Recursive:6.380
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 72, # Partitions: 9, fraction=0.3
# Mean Costs:
#   `Fine`:    636.800
#   Window: 526.400
#   Block: 624.600
#   Recursive:499.400
# Mean Times (s):
#   Fine:    6.306
#   Window: 4.148
#   Block: 3.857
#   Recursive:5.041
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 72, # Partitions: 9, fraction=0.5
# Mean Costs:
#   `Fine`:    1000.000
#   Window: 863.400
#   Block: 971.800
#   Recursive:824.200
# Mean Times (s):
#   Fine:    6.862
#   Window: 4.721
#   Block: 4.468
#   Recursive:5.837
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 72, # Partitions: 9, fraction=0.7
# Mean Costs:
#   `Fine`:    1249.400
#   Window: 1102.800
#   Block: 1207.200
#   Recursive:1055.400
# Mean Times (s):
#   Fine:    8.263
#   Window: 5.908
#   Block: 5.379
#   Recursive:6.872
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 72, # Partitions: 9, fraction=0.9
# Mean Costs:
#   `Fine`:    1106.200
#   Window: 1000.000
#   Block: 1071.600
#   Recursive:937.800
# Mean Times (s):
#   Fine:    13.218
#   Window: 9.761
#   Block: 8.671
#   Recursive:10.123
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 80, # Partitions: 10, fraction=0.3
# Mean Costs:
#   `Fine`:    813.800
#   Window: 661.000
#   Block: 796.000
#   Recursive:612.400
# Mean Times (s):
#   Fine:    9.274
#   Window: 5.974
#   Block: 5.772
#   Recursive:7.589
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 80, # Partitions: 10, fraction=0.5
# Mean Costs:
#   `Fine`:    1267.800
#   Window: 1067.600
#   Block: 1219.800
#   Recursive:994.800
# Mean Times (s):
#   Fine:    9.966
#   Window: 6.954
#   Block: 6.347
#   Recursive:8.427
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 80, # Partitions: 10, fraction=0.7
# Mean Costs:
#   `Fine`:    1608.200
#   Window: 1386.800
#   Block: 1529.600
#   Recursive:1263.800
# Mean Times (s):
#   Fine:    11.637
#   Window: 8.498
#   Block: 7.614
#   Recursive:9.810
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 80, # Partitions: 10, fraction=0.9
# Mean Costs:
#   `Fine`:    1455.000
#   Window: 1281.200
#   Block: 1376.400
#   Recursive:1176.400
# Mean Times (s):
#   Fine:    18.610
#   Window: 13.813
#   Block: 12.044
#   Recursive:15.159
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 88, # Partitions: 11, fraction=0.3
# Mean Costs:
#   `Fine`:    984.200
#   Window: 843.600
#   Block: 967.600
#   Recursive:753.800
# Mean Times (s):
#   Fine:    12.470
#   Window: 8.385
#   Block: 7.720
#   Recursive:10.403
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 88, # Partitions: 11, fraction=0.5
# Mean Costs:
#   `Fine`:    1555.200
#   Window: 1364.200
#   Block: 1500.000
#   Recursive:1229.600
# Mean Times (s):
#   Fine:    13.922
#   Window: 10.049
#   Block: 8.971
#   Recursive:11.814
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 88, # Partitions: 11, fraction=0.7
# Mean Costs:
#   `Fine`:    1989.200
#   Window: 1755.800
#   Block: 1887.600
#   Recursive:1577.600
# Mean Times (s):
#   Fine:    16.614
#   Window: 12.461
#   Block: 10.645
#   Recursive:14.056
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 88, # Partitions: 11, fraction=0.9
# Mean Costs:
#   `Fine`:    1846.200
#   Window: 1670.200
#   Block: 1730.200
#   Recursive:1511.800
# Mean Times (s):
#   Fine:    26.253
#   Window: 19.384
#   Block: 17.075
#   Recursive:21.101
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 96, # Partitions: 12, fraction=0.3
# Mean Costs:
#   `Fine`:    1181.600
#   Window: 972.000
#   Block: 1157.000
#   Recursive:916.800
# Mean Times (s):
#   Fine:    17.053
#   Window: 11.235
#   Block: 10.621
#   Recursive:13.366
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 96, # Partitions: 12, fraction=0.5
# Mean Costs:
#   `Fine`:    1901.400
#   Window: 1622.800
#   Block: 1841.000
#   Recursive:1516.200
# Mean Times (s):
#   Fine:    19.060
#   Window: 13.064
#   Block: 12.068
#   Recursive:15.560
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 96, # Partitions: 12, fraction=0.7
# Mean Costs:
#   `Fine`:    2425.400
#   Window: 2114.000
#   Block: 2327.800
#   Recursive:1941.200
# Mean Times (s):
#   Fine:    21.600
#   Window: 15.806
#   Block: 14.055
#   Recursive:18.160
# =============================================
# =============================================
# Finished 10 iterations for:
#   # Qubits: 96, # Partitions: 12, fraction=0.9
# Mean Costs:
#   `Fine`:    2330.200
#   Window: 2054.200
#   Block: 2193.600
#   Recursive:1900.800
# Mean Times (s):
#   Fine:    33.612
#   Window: 25.706
#   Block: 22.046
#   Recursive:27.323
# =============================================
# Benchmarking completed. Detailed results saved to benchmark_results_FM_fixed_levels_stoch.json
# Aggregated means saved to benchmark_means_FM_fixed_levels_stoch.json

# %%
import os
import json
import time
import numpy as np
from qiskit import transpile
from disqco.graphs.GCP_hypergraph import QuantumCircuitHyperGraph
from disqco.circuits.cp_fraction import cp_fraction
from disqco.parti.FM.FM_main import *
from disqco.parti.FM.multilevel_FM import *
import math as mt

###############################################################################
# Set up JSON file for storing *all* iteration results (detailed data)
###############################################################################
detailed_filename = "benchmark_results_FM_fine_vs_ML.json"

if os.path.exists(detailed_filename):
    with open(detailed_filename, "r") as f:
        detailed_results = json.load(f)
else:
    detailed_results = []

###############################################################################
# Set up JSON file for *aggregated* results (mean cost/time)
###############################################################################
means_filename = "benchmark_means_FM_fine_vs_ML.json"

if os.path.exists(means_filename):
    with open(means_filename, "r") as f:
        mean_results = json.load(f)
else:
    mean_results = []

sizes = range(16, 65, 8)

num_partitions_list = [2,3,4,5,6,7,8]

for i, num_qubits in enumerate(sizes):
    # For each increase of 8 qubits, increase the number of partitions by 1
        num_partitions = num_partitions_list[i]

        # Create an All-to-All network
        qpu_info = [int(num_qubits / num_partitions) + 1 for _ in range(num_partitions)]
        
        # Sweep the fraction parameter from 0.1 to 0.9
        for fraction in np.arange(0.5, 0.6, 0.2):
            
            # Collect data for computing means across 10 iterations
            iteration_data = []

            
            for iteration in range(5):
                print(f"Running iteration {iteration} for {num_qubits} qubits, {num_partitions} partitions, fraction={fraction}")
                
                # -------------------------
                # 1. Define/redefine circuit
                # -------------------------
                circuit = cp_fraction(num_qubits, num_qubits, fraction)
                base_graph = QuantumCircuitHyperGraph(circuit, group_gates=True, anti_diag=True)
                depth = base_graph.depth
                num_levels = int(mt.log2(depth))
                initial_assignment = set_initial_partitions(qpu_info,num_qubits, depth ,num_partitions, reduced=True)
                
                # -------------------------
                # 2. Fine-grained partitioning
                # -------------------------
                graph_list = [base_graph]
                mapping_list = [{i : set([i]) for i in range(depth)}]

                assignment_list_f, cost_list_f, time_list_f = multilevel_FM(graph_list,
                                                                    mapping_list,
                                                                    initial_assignment,
                                                                        qpu_info,
                                                                        limit = num_qubits * depth * 0.125,
                                                                        pass_list= [5*(num_levels+2)],
                                                                        stochastic=True,
                                                                        lock_nodes=False,
                                                                        log = False,
                                                                        add_initial = False,
                                                                        costs = None)
                total_time_f = sum(time_list_f)
                min_cost_f = min(cost_list_f)
                # -------------------------
                # 3. Window-based refinement
                # -------------------------

                assignment_list_w, cost_list_w, time_list_w = MLFM_window(base_graph, 
                    num_levels=num_levels,
                    initial_assignment=initial_assignment,  
                    qpu_info= qpu_info, 
                    limit = num_qubits,
                    pass_list= [5]*(num_levels+2), 
                    stochastic=False, 
                    lock_nodes=False,
                    log = False,
                    add_initial = False,
                    costs = None)
                
                total_time_w = sum(time_list_w)
                min_cost_w = min(cost_list_w)

                
                # -------------------------
                # 4. Block refinement
                # -------------------------
                assignment_list_b, cost_list_b, time_list_b = MLFM_blocks(base_graph,
                                                num_levels=num_levels+1,
                                                initial_assignment=initial_assignment,  
                                                qpu_info = qpu_info, 
                                                limit = num_qubits , 
                                                pass_list= [5]*(num_levels+2), 
                                                stochastic=True, 
                                                lock_nodes=False,
                                                log = False,
                                                add_initial = False,
                                                costs = None)
                
                total_time_b = sum(time_list_b)
                min_cost_b = min(cost_list_b)
                
                # -------------------------
                # 5. Recursive refinement
                # -------------------------
                assignment_list_r, cost_list_r, time_list_r = MLFM_recursive(base_graph,
                                            initial_assignment,  
                                            qpu_info, 
                                            limit = num_qubits , 
                                            pass_list= [5]*(num_levels+2), 
                                            stochastic=True, 
                                            lock_nodes=False,
                                            log = False,
                                            add_initial = False,
                                            costs = None)
                
                total_time_r = sum(time_list_r)
                min_cost_r = min(cost_list_r)

                
                # -------------------------
                # 6. Store iteration-level results
                # -------------------------
                result_entry = {
                    "num_qubits": num_qubits,
                    "num_partitions": num_partitions,
                    "fraction": float(fraction),
                    "iteration": iteration,
                    "f_cost": min_cost_f,
                    "w_cost": min_cost_w,
                    "b_cost": min_cost_b,
                    "r_cost":  min_cost_r,
                    "time_f": total_time_f,
                    "time_w": total_time_w,
                    "time_b": total_time_b,
                    "time_r": total_time_r,
                }
                
                detailed_results.append(result_entry)
                iteration_data.append(result_entry)
                
                # Update detailed JSON right away
                with open(detailed_filename, "w") as f:
                    json.dump(detailed_results, f, indent=2)
            
            # ---------------------------------------------------------------------
            # After 10 iterations, compute the means and log them
            # ---------------------------------------------------------------------
            f_cost_list = [x["f_cost"] for x in iteration_data]
            w_cost_list = [x["w_cost"] for x in iteration_data]
            b_cost_list = [x["b_cost"] for x in iteration_data]
            r_cost_list = [x["r_cost"] for x in iteration_data]
            
            f_time_list = [x["time_f"] for x in iteration_data]
            w_time_list = [x["time_w"] for x in iteration_data]
            b_time_list = [x["time_b"] for x in iteration_data]
            r_time_list = [x["time_r"] for x in iteration_data]
            
            mean_f_cost = float(np.mean(f_cost_list))
            mean_w_cost = float(np.mean(w_cost_list))
            mean_b_cost = float(np.mean(b_cost_list))
            mean_r_cost = float(np.mean(r_cost_list))
            
            mean_f_time = float(np.mean(f_time_list))
            mean_w_time = float(np.mean(w_time_list))
            mean_b_time = float(np.mean(b_time_list))
            mean_r_time = float(np.mean(r_time_list))
            
            # Print to console for quick logging
            print("=============================================")
            print(f"Finished 10 iterations for:")
            print(f"  # Qubits: {num_qubits}, # Partitions: {num_partitions}, fraction={fraction}")
            print("Mean Costs:")
            print(f"  `Fine`:    {mean_f_cost:.3f}")
            print(f"  Window: {mean_w_cost:.3f}")
            print(f"  Block: {mean_b_cost:.3f}")
            print(f"  Recursive:{mean_r_cost:.3f}")
            print("Mean Times (s):")
            print(f"  Fine:    {mean_f_time:.3f}")
            print(f"  Window: {mean_w_time:.3f}")
            print(f"  Block: {mean_b_time:.3f}")
            print(f"  Recursive:{mean_r_time:.3f}")
            print("=============================================")
            
            # Store the aggregated means in a separate JSON
            mean_entry = {
                "num_qubits": num_qubits,
                "num_partitions": num_partitions,
                "fraction": float(fraction),
                "mean_f_cost": mean_f_cost,
                "mean_w_cost": mean_w_cost,
                "mean_b_cost": mean_b_cost,
                "mean_r_cost": mean_r_cost,
                "mean_f_time": mean_f_time,
                "mean_w_time": mean_w_time,
                "mean_b_time": mean_b_time,
                "mean_r_time": mean_r_time,
            }
            
            mean_results.append(mean_entry)
            
            # Update the means JSON file
            with open(means_filename, "w") as f:
                json.dump(mean_results, f, indent=2)

print("Benchmarking completed. Detailed results saved to", detailed_filename)
print("Aggregated means saved to", means_filename)
# Out:
# Running iteration 0 for 16 qubits, 2 partitions, fraction=0.5
# Number of hypergraphs coarsened: 5
# Running iteration 1 for 16 qubits, 2 partitions, fraction=0.5
# Number of hypergraphs coarsened: 5
# Running iteration 2 for 16 qubits, 2 partitions, fraction=0.5
# Number of hypergraphs coarsened: 5
# Running iteration 3 for 16 qubits, 2 partitions, fraction=0.5
# Number of hypergraphs coarsened: 5
# Running iteration 4 for 16 qubits, 2 partitions, fraction=0.5
# Number of hypergraphs coarsened: 5
# =============================================
# Finished 10 iterations for:
#   # Qubits: 16, # Partitions: 2, fraction=0.5
# Mean Costs:
#   `Fine`:    13.400
#   Window: 11.600
#   Block: 11.400
#   Recursive:10.800
# Mean Times (s):
#   Fine:    0.090
#   Window: 0.052
#   Block: 0.062
#   Recursive:0.064
# =============================================
# Running iteration 0 for 24 qubits, 3 partitions, fraction=0.5
# Number of hypergraphs coarsened: 6
# Running iteration 1 for 24 qubits, 3 partitions, fraction=0.5
# Number of hypergraphs coarsened: 6
# Running iteration 2 for 24 qubits, 3 partitions, fraction=0.5
# Number of hypergraphs coarsened: 6
# Running iteration 3 for 24 qubits, 3 partitions, fraction=0.5
# Number of hypergraphs coarsened: 6
# Running iteration 4 for 24 qubits, 3 partitions, fraction=0.5
# Number of hypergraphs coarsened: 6
# =============================================
# Finished 10 iterations for:
#   # Qubits: 24, # Partitions: 3, fraction=0.5
# Mean Costs:
#   `Fine`:    50.200
#   Window: 44.400
#   Block: 42.600
#   Recursive:43.000
# Mean Times (s):
#   Fine:    0.323
#   Window: 0.133
#   Block: 0.201
#   Recursive:0.230
# =============================================
# Running iteration 0 for 32 qubits, 4 partitions, fraction=0.5
# Number of hypergraphs coarsened: 6
# Running iteration 1 for 32 qubits, 4 partitions, fraction=0.5
# Number of hypergraphs coarsened: 6
# Running iteration 2 for 32 qubits, 4 partitions, fraction=0.5
# Number of hypergraphs coarsened: 6
# Running iteration 3 for 32 qubits, 4 partitions, fraction=0.5
# Number of hypergraphs coarsened: 6
# Running iteration 4 for 32 qubits, 4 partitions, fraction=0.5
# Number of hypergraphs coarsened: 6
# =============================================
# Finished 10 iterations for:
#   # Qubits: 32, # Partitions: 4, fraction=0.5
# Mean Costs:
#   `Fine`:    116.200
#   Window: 108.400
#   Block: 100.200
#   Recursive:97.400
# Mean Times (s):
#   Fine:    1.039
#   Window: 0.380
#   Block: 0.567
#   Recursive:0.544
# =============================================
# Running iteration 0 for 40 qubits, 5 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 1 for 40 qubits, 5 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 2 for 40 qubits, 5 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 3 for 40 qubits, 5 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 4 for 40 qubits, 5 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# =============================================
# Finished 10 iterations for:
#   # Qubits: 40, # Partitions: 5, fraction=0.5
# Mean Costs:
#   `Fine`:    208.000
#   Window: 187.600
#   Block: 178.400
#   Recursive:172.200
# Mean Times (s):
#   Fine:    2.175
#   Window: 0.780
#   Block: 1.168
#   Recursive:1.259
# =============================================
# Running iteration 0 for 48 qubits, 6 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 1 for 48 qubits, 6 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 2 for 48 qubits, 6 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 3 for 48 qubits, 6 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 4 for 48 qubits, 6 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# =============================================
# Finished 10 iterations for:
#   # Qubits: 48, # Partitions: 6, fraction=0.5
# Mean Costs:
#   `Fine`:    328.000
#   Window: 318.400
#   Block: 286.600
#   Recursive:277.400
# Mean Times (s):
#   Fine:    4.202
#   Window: 1.349
#   Block: 2.092
#   Recursive:2.152
# =============================================
# Running iteration 0 for 56 qubits, 7 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 1 for 56 qubits, 7 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 2 for 56 qubits, 7 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 3 for 56 qubits, 7 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 4 for 56 qubits, 7 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# =============================================
# Finished 10 iterations for:
#   # Qubits: 56, # Partitions: 7, fraction=0.5
# Mean Costs:
#   `Fine`:    486.000
#   Window: 448.600
#   Block: 434.200
#   Recursive:408.400
# Mean Times (s):
#   Fine:    7.300
#   Window: 2.302
#   Block: 3.516
#   Recursive:3.342
# =============================================
# Running iteration 0 for 64 qubits, 8 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 1 for 64 qubits, 8 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 2 for 64 qubits, 8 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 3 for 64 qubits, 8 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# Running iteration 4 for 64 qubits, 8 partitions, fraction=0.5
# Number of hypergraphs coarsened: 7
# =============================================
# Finished 10 iterations for:
#   # Qubits: 64, # Partitions: 8, fraction=0.5
# Mean Costs:
#   `Fine`:    655.800
#   Window: 679.800
#   Block: 593.200
#   Recursive:568.000
# Mean Times (s):
#   Fine:    14.232
#   Window: 3.906
#   Block: 5.935
#   Recursive:5.217
# =============================================
# Benchmarking completed. Detailed results saved to benchmark_results_FM_fine_vs_ML.json
# Aggregated means saved to benchmark_means_FM_fine_vs_ML.json

# %%
# Out:
# Created dat_files/fraction_0.3_cost.dat and dat_files/fraction_0.3_time.dat
# Created dat_files/fraction_0.5_cost.dat and dat_files/fraction_0.5_time.dat
# Created dat_files/fraction_0.7_cost.dat and dat_files/fraction_0.7_time.dat
# Created dat_files/fraction_0.9_cost.dat and dat_files/fraction_0.9_time.dat
# Done generating .dat files by fraction.

# %%
# Out:
# Saved figure: fraction_0.3_cost.png
# Saved figure: fraction_0.5_cost.png
# Saved figure: fraction_0.7_cost.png
# Saved figure: fraction_0.9_cost.png
# Saved figure: fraction_0.3_time.png
# Saved figure: fraction_0.5_time.png
# Saved figure: fraction_0.7_time.png
# Saved figure: fraction_0.9_time.png
