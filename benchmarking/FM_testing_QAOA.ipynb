# %%
import os
import json
import time
import numpy as np
from qiskit import transpile
from qiskit.circuit.library import QFT
from MLFM_GCP.circuits.QAOA import QAOA_random
from MLFM_GCP.graphs.GCP_hypergraph import QuantumCircuitHyperGraph
from MLFM_GCP.partitioning.FM.FM_main import *
from MLFM_GCP.partitioning.FM.multilevel_FM import *

###############################################################################
# Set up JSON file for storing *all* iteration results (detailed data)
###############################################################################
detailed_filename = "benchmark_results_MLFM-R_QAOA_2_part.json"

if os.path.exists(detailed_filename):
    with open(detailed_filename, "r") as f:
        detailed_results = json.load(f)
else:
    detailed_results = []

###############################################################################
# Set up JSON file for *aggregated* results (mean cost/time)
###############################################################################
means_filename = "benchmark_means_MLFM-R_QAOA_2_part.json"

if os.path.exists(means_filename):
    with open(means_filename, "r") as f:
        mean_results = json.load(f)
else:
    mean_results = []

sizes = range(16, 96, 8)

for i, num_qubits in enumerate(sizes):
    # For each increase of 8 qubits, increase the number of partitions by 1
    num_partitions = 2

    # Create an All-to-All network
    qpu_info = [int(num_qubits / num_partitions) + 1 for _ in range(num_partitions)]
    
    # Sweep the fraction parameter from 0.1 to 0.9
        # Collect data for computing means across 10 iterations
    iteration_data = []
    for iteration in range(5):
        
        # -------------------------
        # 1. Define/redefine circuit
        # -------------------------

        # base_graph = build_circuit(num_qubits,fraction=fraction,group_gates=True)
        circuit = QAOA_random(num_qubits,prob=0.5, reps=1)
        circuit = transpile(circuit, basis_gates = ['u','cp'])
        base_graph = QuantumCircuitHyperGraph(circuit,group_gates=True)
        depth = base_graph.depth
        initial_assignment = set_initial_partitions(qpu_info,num_qubits, depth ,num_partitions, reduced=True)
        
        # -------------------------
        # 2. Fine-grained partitioning
        # -------------------------
        graph_list = [base_graph]
        mapping_list = [{i : set([i]) for i in range(depth)}]

        assignment_list_f, cost_list_f, time_list_f = multilevel_FM(graph_list,
                                                                mapping_list,
                                                                initial_assignment,
                                                                qpu_info,
                                                                limit = num_qubits*depth/8,
                                                                pass_list= [50],
                                                                stochastic=True,
                                                                lock_nodes=False,
                                                                log = False,
                                                                add_initial = False,
                                                                costs = None)
        total_time_f = sum(time_list_f)
        min_cost_f = min(cost_list_f)
        # -------------------------
        # 3. Window-based refinement
        # -------------------------

        assignment_list_w, cost_list_w, time_list_w = MLFM_window(base_graph, 
            num_levels=8,
            initial_assignment=initial_assignment,  
            qpu_info= qpu_info, 
            limit = None, 
            pass_list= None, 
            stochastic=True, 
            lock_nodes=True,
            log = False,
            add_initial = False,
            costs = None)
        
        total_time_w = sum(time_list_w)
        min_cost_w = min(cost_list_w)

        
        # -------------------------
        # 4. Block refinement
        # -------------------------
        assignment_list_b, cost_list_b, time_list_b = MLFM_blocks(base_graph,
                                        num_blocks=8,
                                        initial_assignment=initial_assignment,  
                                        qpu_info= qpu_info, 
                                        limit = None, 
                                        pass_list= None, 
                                        stochastic=True, 
                                        lock_nodes=True,
                                        log = False,
                                        add_initial = False,
                                        costs = None,
                                        full = False)
        
        total_time_b = sum(time_list_b)
        min_cost_b = min(cost_list_b)
        
        # -------------------------
        # 5. Recursive refinement
        # -------------------------
        assignment_list_r, cost_list_r, time_list_r = MLFM_recursive(base_graph,
                                    initial_assignment,  
                                    qpu_info, 
                                    limit = 'None', 
                                    pass_list= None, 
                                    stochastic=True, 
                                    lock_nodes=False,
                                    log = False,
                                    add_initial = False,
                                    costs = None)
        
        total_time_r = sum(time_list_r)
        min_cost_r = min(cost_list_r)

        
        # -------------------------
        # 6. Store iteration-level results
        # -------------------------
        result_entry = {
            "num_qubits": num_qubits,
            "num_partitions": num_partitions,
            "iteration": iteration,
            "f_cost": min_cost_f,
            "w_cost": min_cost_w,
            "b_cost": min_cost_b,
            "r_cost":  min_cost_r,
            "time_f": total_time_f,
            "time_w": total_time_w,
            "time_b": total_time_b,
            "time_r": total_time_r,
        }
        
        detailed_results.append(result_entry)
        iteration_data.append(result_entry)
        
        # Update detailed JSON right away
        with open(detailed_filename, "w") as f:
            json.dump(detailed_results, f, indent=2)
    
    # ---------------------------------------------------------------------
    # After 10 iterations, compute the means and log them
    # ---------------------------------------------------------------------
    f_cost_list = [x["f_cost"] for x in iteration_data]
    w_cost_list = [x["w_cost"] for x in iteration_data]
    b_cost_list = [x["b_cost"] for x in iteration_data]
    r_cost_list = [x["r_cost"] for x in iteration_data]
    
    f_time_list = [x["time_f"] for x in iteration_data]
    w_time_list = [x["time_w"] for x in iteration_data]
    b_time_list = [x["time_b"] for x in iteration_data]
    r_time_list = [x["time_r"] for x in iteration_data]
    
    mean_f_cost = float(np.mean(f_cost_list))
    mean_w_cost = float(np.mean(w_cost_list))
    mean_b_cost = float(np.mean(b_cost_list))
    mean_r_cost = float(np.mean(r_cost_list))
    
    mean_f_time = float(np.mean(f_time_list))
    mean_w_time = float(np.mean(w_time_list))
    mean_b_time = float(np.mean(b_time_list))
    mean_r_time = float(np.mean(r_time_list))
    
    # Print to console for quick logging
    print("=============================================")
    print(f"Finished 10 iterations for:")
    print(f"  # Qubits: {num_qubits}, # Partitions: {num_partitions}")
    print("Mean Costs:")
    print(f"  `Fine`:    {mean_f_cost:.3f}")
    print(f"  Window: {mean_w_cost:.3f}")
    print(f"  Block: {mean_b_cost:.3f}")
    print(f"  Recursive:{mean_r_cost:.3f}")
    print("Mean Times (s):")
    print(f"  Fine:    {mean_f_time:.3f}")
    print(f"  Window: {mean_w_time:.3f}")
    print(f"  Block: {mean_b_time:.3f}")
    print(f"  Recursive:{mean_r_time:.3f}")
    print("=============================================")
    
    # Store the aggregated means in a separate JSON
    mean_entry = {
        "num_qubits": num_qubits,
        "num_partitions": num_partitions,
        "mean_f_cost": mean_f_cost,
        "mean_w_cost": mean_w_cost,
        "mean_b_cost": mean_b_cost,
        "mean_r_cost": mean_r_cost,
        "mean_f_time": mean_f_time,
        "mean_w_time": mean_w_time,
        "mean_b_time": mean_b_time,
        "mean_r_time": mean_r_time,
    }
    
    mean_results.append(mean_entry)
    
    # Update the means JSON file
    with open(means_filename, "w") as f:
        json.dump(mean_results, f, indent=2)

print("Benchmarking completed. Detailed results saved to", detailed_filename)
print("Aggregated means saved to", means_filename)
# Out:
# =============================================
# Finished 10 iterations for:
#   # Qubits: 16, # Partitions: 2
# Mean Costs:
#   `Fine`:    8.200
#   Window: 7.000
#   Block: 7.600
#   Recursive:7.000
# Mean Times (s):
#   Fine:    1.341
#   Window: 0.990
#   Block: 1.040
#   Recursive:0.630
# =============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 101
#      95 min_cost_w = min(cost_list_w)
#      98 # -------------------------
#      99 # 4. Block refinement
#     100 # -------------------------
# --> 101 assignment_list_b, cost_list_b, time_list_b = MLFM_blocks(base_graph,
#     102                                 num_blocks=8,
#     103                                 initial_assignment=initial_assignment,
#     104                                 qpu_info= qpu_info,
#     105                                 limit = None,
#     106                                 pass_list= None,
#     107                                 stochastic=True,
#     108                                 lock_nodes=True,
#     109                                 log = False,
#     110                                 add_initial = False,
#     111                                 costs = None,
#     112                                 full = False)
#     114 total_time_b = sum(time_list_b)
#     115 min_cost_b = min(cost_list_b)
#
# File ~/MLQCP_FM/src/MLFM_GCP/partitioning/FM/multilevel_FM.py:194, in MLFM_blocks(graph, num_blocks, initial_assignment, qpu_info, limit, pass_list, stochastic, lock_nodes, log, add_initial, costs, full)
#     180     assignment_list_c, cost_list_c, time_list_c = multilevel_FM(coarsened_hypergraphs=coarse_graph_list,
#     181                                     mapping_list=coarse_mapping_list,
#     182                                     initial_assignment=initial_assignment,
#    (...)
#     189                                     add_initial=add_initial,
#     190                                     costs=costs)
#     192     initial_assignment = assignment_list_c[np.argmin(cost_list_c)]
# --> 194 assignment_list, cost_list, time_list = multilevel_FM(coarsened_hypergraphs=graph_list,
#     195                                         mapping_list=mapping_list,
#     196                                         initial_assignment=initial_assignment,
#     197                                         qpu_info=qpu_info,
#     198                                         limit = limit,
#     199                                         pass_list=pass_list,
#     200                                         stochastic=stochastic,
#     201                                         lock_nodes=lock_nodes,
#     202                                         log=log,
#     203                                         add_initial=add_initial,
#     204                                         costs=costs)
#     205 if full:
#     206     assignment_list = assignment_list_c + assignment_list
#
# File ~/MLQCP_FM/src/MLFM_GCP/partitioning/FM/multilevel_FM.py:77, in multilevel_FM(coarsened_hypergraphs, mapping_list, initial_assignment, qpu_info, limit, pass_list, stochastic, lock_nodes, log, add_initial, costs, level_limit)
#      75 passes = pass_list[i]
#      76 start = time.time()
# ---> 77 best_cost_pass, best_assignment, _ = run_FM(
#      78     hypergraph=graph,            # This stage's coarsened hypergraph
#      79     initial_assignment=initial_assignment,
#      80     qpu_info=qpu_info,
#      81     num_partitions=num_partitions,
#      82     limit=limit,
#      83     max_gain=max_gain,
#      84     passes=passes,
#      85     stochastic=stochastic,
#      86     active_nodes=active_nodes,
#      87     log = log,
#      88     add_initial=add_initial,
#      89     costs=costs
#      90 )
#      91 end = time.time()
#      92 level_time = end - start
#
# File ~/MLQCP_FM/src/MLFM_GCP/partitioning/FM/FM_main.py:92, in run_FM(hypergraph, initial_assignment, qpu_info, num_partitions, limit, max_gain, passes, stochastic, active_nodes, log, add_initial, costs)
#      89 # print("Starting FM passes...")
#      90 for n in range(passes):
#      91     # print(f"Pass number: {n}")
# ---> 92     assignment_list, gain_list = FM_pass(
#      93         hypergraph, max_gain, initial_assignment,
#      94         num_partitions, qpu_info, costs, limit, active_nodes = active_nodes
#      95     )
#      97     # Decide how to pick new assignment depending on stochastic or not
#      98     if stochastic:
#
# File ~/MLQCP_FM/src/MLFM_GCP/partitioning/FM/FM_main.py:44, in FM_pass(hypergraph, max_gain, assignment, num_partitions, qpu_info, costs, limit, active_nodes)
#      41 destination = action[2]
#      42 source = assignment[node[1]][node[0]]
# ---> 44 assignment_new, array, buckets = take_action_and_update_dict_counts(hypergraph,node,destination,array,buckets,num_partitions,lock_dict,assignment,costs)
#      46 # assignment_new, array, buckets = take_action_and_update_dict_simple(hypergraph,node,destination,array,buckets,num_partitions,lock_dict,assignment,costs)
#      48 update_spaces(node,source,destination,spaces)
#
# File ~/MLQCP_FM/src/MLFM_GCP/partitioning/FM/FM_methods.py:868, in take_action_and_update_dict_counts(hypergraph, node, destination, array, buckets, num_partitions, lock_dict, assignment, costs)
#     865 next_root_counts_b, source1 = update_counts(root_counts_pre, next_root_node, next_destination, assignment)
#     866 full_config_b = update_config_from_counts(conf,next_root_counts_b,rec_counts_pre,source1,next_destination)
# --> 868 next_root_counts_ab, source2 = update_counts(root_counts_a, next_root_node, next_destination, assignment_new)
#     869 full_config_ab = update_config_from_counts(conf_a,next_root_counts_ab,rec_counts_a,source2,next_destination)
#     872 delta_gain = cost_a - cost - costs[full_config_ab] + costs[full_config_b]
#
# File ~/MLQCP_FM/src/MLFM_GCP/partitioning/FM/FM_methods.py:155, in update_counts(counts, node, destination, assignment)
#     153 def update_counts(counts,node,destination,assignment):
#     154     partition = assignment[node[1]][node[0]]
# --> 155     new_counts = copy.deepcopy(list(counts))
#     156     new_counts[partition] -= 1
#     157     new_counts[destination] += 1
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/copy.py:192, in _deepcopy_list(x, memo, deepcopy)
#     189 d[weakref.ref] = _deepcopy_atomic
#     190 d[property] = _deepcopy_atomic
# --> 192 def _deepcopy_list(x, memo, deepcopy=deepcopy):
#     193     y = []
#     194     memo[id(x)] = y
#
# KeyboardInterrupt:
