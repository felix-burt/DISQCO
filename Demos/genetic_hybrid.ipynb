# %%
from src.genetic_algorithm import Genetic_Partitioning
import multiprocessing as mp

from circuits.cp_fraction import cp_fraction
from src.GCP_hypergraph import QuantumCircuitHyperGraph
from qiskit import transpile
from src.FM_methods import set_initial_partitions
from qiskit.circuit.library import QFT, QuantumVolume, EfficientSU2
from circuits.QAOA import QAOA_random
import numpy as np

num_qubits = 24
num_partitions = 2
qpu_size = int(num_qubits / num_partitions) + 1
qpu_info = [qpu_size] * num_partitions

circuit = cp_fraction(  num_qubits=num_qubits,
                        depth=num_qubits,
                        fraction= 0.5 )

# circuit = QFT(num_qubits, do_swaps=False)

# circuit = QuantumVolume(num_qubits, depth=num_qubits)

# circuit = QAOA_random(num_qubits, prob = 0.9, reps = 1)

# ansatz = EfficientSU2(num_qubits, entanglement='full', reps=1)

# param_values = np.random.rand(len(ansatz.parameters))
# param_dict = dict(zip(ansatz.parameters, param_values))
# circuit = ansatz.assign_parameters(param_dict)


circuit = transpile(circuit, basis_gates = ['cp', 'u'])

depth = circuit.depth()

graph = QuantumCircuitHyperGraph(num_qubits=num_qubits, depth=depth)
graph.map_circuit_to_hypergraph(circuit, group_gates = True, anti_diag = False)
assignment = set_initial_partitions(qpu_info, num_qubits, depth, num_partitions, reduced = True)

from src.joint_hyperedges import *
from src.FM_methods import get_all_configs, get_all_costs

configs = get_all_configs(num_partitions)
costs = get_all_costs(configs)




num_generations = 100
population_size = 10000
mutation_rate = 0.9

genetic_partition = Genetic_Partitioning(circuit, qpu_info, costs, multi_process=False, gate_packing=True)

genetic_partition.run(population_size, num_generations, mutation_rate=mutation_rate, multi_process=False,log_frequency=10)
# Out:
# [46, 48, 44, 45, 45, 45, 45, 44, 51, 49, 43, 39, 34, 39, 39, 43, 42, 42, 46, 48, 47, 38, 42, 42, 41, 45, 52, 42, 42, 46, 50, 48, 44, 41, 47, 41, 45, 42, 48, 43, 47, 46, 46, 46, 38, 45, 48, 45, 52, 47, 43, 47, 43, 48, 46, 50, 40, 47, 43, 45, 45, 50, 48, 44, 46, 43, 44, 40, 38, 49, 44, 38, 41, 47, 46, 45, 47, 46, 48, 44, 47, 49, 48, 41, 46, 40, 40, 51, 43, 48, 41, 48, 47, 46, 46, 45, 48, 48, 44, 45, 48, 51, 44, 43, 40, 47, 51, 44, 44, 51, 50, 49, 46, 47, 43, 49, 45, 41, 43, 43, 47, 47, 47, 48, 44, 48, 47, 42, 43, 40, 51, 46, 53, 40, 49, 49, 46, 45, 49, 44, 43, 44, 40, 45, 47, 42, 46, 49, 42, 48, 43, 49, 46, 41, 50, 42, 43, 50, 44, 44, 51, 40, 51, 47, 40, 42, 42, 41, 44, 41, 53, 47, 45, 39, 47, 44, 47, 45, 45, 47, 41, 43, 45, 47, 45, 44, 49, 44, 41, 50, 47, 37, 45, 48, 42, 39, 42, 52, 44, 45, 43, 43, 48, 43, 44, 50, 53, 38, 45, 47, 41, 50, 41, 40, 40, 47, 46, 51, 44,
, 47, 43, 50, 44, 46, 46, 39, 46, 47, 43, 44, 46, 46, 48, 49, 44, 42, 46, 39, 50, 46, 49, 48, 52, 47, 47, 48, 45, 44, 40, 50, 49, 54, 48, 45, 38, 41, 40, 37, 42, 46, 45, 49, 42, 46, 46, 45, 48, 47, 51, 47, 43, 46, 46, 50, 47, 42, 50, 46, 41, 49, 40, 47, 47, 46, 46, 43, 46, 44, 43, 46, 50, 43, 40, 50, 45, 40, 45, 39, 41, 37, 50, 43, 44, 42, 38, 45, 39, 49, 38, 43, 46, 46, 47, 45, 42, 46, 43, 44, 47, 48, 49, 41, 44, 43, 46, 42, 40, 49, 45, 48, 49, 50, 39, 49, 46, 48, 44, 47, 42, 45, 50, 43, 43, 48, 54, 48, 45, 42, 41, 44, 46, 36, 49, 43, 41, 47, 43, 47, 48, 44, 41, 51, 42, 48, 37, 42, 51, 48, 48, 49, 46, 42, 40, 44, 49, 41, 46, 49, 45, 47, 45, 51, 48, 39, 40, 49, 44, 36, 39, 42, 42, 41, 45, 46, 45, 45, 46, 48, 48, 43, 45, 45, 46, 48, 42, 45, 40, 43, 50, 43, 44, 50, 44, 48, 47, 49, 46, 46, 43, 48, 42, 44, 44, 45, 48, 47, 47, 47, 41, 49, 46, 45, 41, 45, 43, 44, 43, 52, 47, 47, 51, 45, 43, 47, 49, 40, 45, 42, 49, 39, 41, 44, 43, 41, 42, 48, 46, 49, 46, 48, 43, 46, 43, 45, 45, 38, 52, 48, 49, 44, 44, 44, 44, 45, 43, 43, 45, 47, 46, 47, 43, 43, 48, 47, 48, 48, 42, 48, 45, 46, 48, 48, 43, 40, 42, 45, 49, 41, 42, 43, 50, 45, 40, 41, 46, 47, 52, 44, 47, 45, 42, 46, 48, 51, 49, 40, 47, 43, 46, 43, 47, 49, 47, 47, 40, 49, 49, 44, 49, 42, 37, 45, 49, 43, 49, 51, 49, 50, 43, 48, 47, ...
# Current best cut: 33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 57
#      53 mutation_rate = 0.9
#      55 genetic_partition = Genetic_Partitioning(circuit, qpu_info, costs, multi_process=False, gate_packing=True)
# ---> 57 genetic_partition.run(population_size, num_generations, mutation_rate=mutation_rate, multi_process=False,log_frequency=10)
#
# File ~/MLQCP_FM/src/genetic_algorithm.py:78, in Genetic_Partitioning.run(self, pop_size, num_generations, random_start, mutation_rate, search_method, search_number, log, log_frequency, multi_process, choose_initial)
#      76 for _ in range(int(len(population)/2)-1):
#      77     parents = selection_pair(population,probabilities)
# ---> 78     offspring_a, offspring_b = create_offspring(parents,
#      79                                                 self.qpu_info,
#      80                                                 self.num_qubits_log,
#      81                                                 self.num_layers,
#      82                                                 self.num_partitions,
#      83                                                 self.graph,
#      84                                                 self.costs,
#      85                                                 mutation_rate)
#      86     next_generation.append(offspring_a)
#      87     next_generation.append(offspring_b)
#
# File ~/MLQCP_FM/src/genetic_algorithm.py:191, in create_offspring(parents, qpu_info, num_qubits, num_layers, num_partitions, graph, costs, mutation_rate, number)
#     183 offspring_a, offspring_b = crossover(parents[0], parents[1], 0.5)
#     184 if random.random() < mutation_rate:
#     185     # if random.random() > 0.5:
#     186     #     offspring_a = swap_mutation_propogate(offspring_a, num_qubits, num_layers,num=1,prob=1)
#    (...)
#     189     #     offspring_a = match_mutation(offspring_a, num_layers,num=1, prob=1)
#     190     #     offspring_b = match_mutation(offspring_b, num_layers,num=1, prob=1)
# --> 191     offspring_a = search_mutation(graph, offspring_a, num_partitions, qpu_info, num_qubits, num_layers, costs, number)
#     192     offspring_b = search_mutation(graph, offspring_b, num_partitions, qpu_info, num_qubits, num_layers ,costs, number)
#     194 cut_a = fitness_function(graph,offspring_a,num_partitions,costs,qpu_info,num_layers)
#
# File ~/MLQCP_FM/src/genetic_algorithm.py:431, in search_mutation(graph, partition, num_partitions, qpu_info, num_qubits_log, num_layers, costs, number)
#     429         destination = part
#     430         break
# --> 431 gain, stop = calculate_cost_interval(graph,partition,qpu_info,start,destination,qubit,num_layers,num_partitions,costs)
#     432 if gain < best:
#     433     best = gain
#
# File ~/MLQCP_FM/src/genetic_algorithm.py:402, in calculate_cost_interval(graph, partition, qpu_info, start, destination, qubit, num_layers, num_partitions, costs)
#     400 node = (qubit,n)
#     401 if is_space(partition, qpu_info, destination, n):
# --> 402     cost = find_gain(graph, node, destination, partition, num_partitions, costs)
#     403     gain += cost
#     404     n += 1
#
# File ~/MLQCP_FM/src/genetic_algorithm.py:386, in find_gain(hypergraph, node, destination, assignment, num_partitions, costs, log)
#     383 config1 = get_full_config(root_config,rec_config)
#     384 cost1 = costs[config1]
# --> 386 root_config, rec_config = map_hedge_to_config(hypergraph,edge,assignment_new,num_partitions)
#     387 config2 = get_full_config(root_config,rec_config)
#     388 cost2 = costs[config2]
#
# File ~/MLQCP_FM/src/hypergraph_methods.py:57, in map_hedge_to_config(hypergraph, hedge, assignment, num_partitions)
#      55 def map_hedge_to_config(hypergraph,hedge,assignment,num_partitions):
#      56     root_counts,rec_counts = hedge_k_counts(hypergraph,hedge,assignment,num_partitions,set_attrs=False)
# ---> 57     root_config,rec_config = counts_to_configs(root_counts,rec_counts)
#      58     # print(root_config,rec_config)
#      59     return (tuple(root_config),tuple(rec_config))
#
# File ~/MLQCP_FM/src/hypergraph_methods.py:44, in counts_to_configs(root_counts, rec_counts)
#      42 root_config = []
#      43 rec_config = []
# ---> 44 for x,y in zip(root_counts,rec_counts):
#      45     if x > 0:
#      46         root_config.append(1)
#
# KeyboardInterrupt:
